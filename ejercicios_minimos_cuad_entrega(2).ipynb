# %% [markdown]
# <a href="https://colab.research.google.com/github/gachet/mis-colabs/blob/master/ejercicios_minimos_cuad_entrega(2).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Ejercicios Mínimos Cuadrados. Utilizar las ecuaciones normales para encontrar:
# 1. los coeficientes  pedidos
# 2. el coeficiente de determinación
# 3. la sumatoria de los cuadrados de los errores y
# 4. hacer la gráfica de los datos y de la función ajustada.

# %% [markdown]
# ### 1- La tabla siguiente muestra el número de transistores en un procesador Intel desde 1970, encuentre los coeficientes del modelo $y=c_{1}*e^{c_{2}*t}$ correspondiente a estos datos. Considerar el año 1970 como el año 0.

# %%
from IPython.display import Image
Image(filename="tablas/uno.png")

# %% [markdown]
# #### Solución $$transistores = 1335.3*e^{0.3546*años} $$
# Coeficiente de determinación es:  0.9867174478935928<br>
# suma_cuad_err 0.06276510644199446

# %% [markdown]
# ### 2.- La concentración $y$ de una droga en la sangre se describe de acuerdo al modelo $y=c_{1}*t*e^{c_{2}*t}$. Linealizar la ecuación y calcular $c_{1}$ y $c_{2}$ mediante mínimos cuadrados dados los datos siguientes:

# %%
from IPython.display import Image
Image(filename="tablas/dos.png")

# %% [markdown]
# #### Solución $$concentracion = 9.79*horas*e^{-0.21*horas} $$
# Coeficiente de determinación es:  0.9986186936173885 <br>
# suma_cuad_err   0.5558178376791499

# %% [markdown]
# ### 3.- La siguiente tabla muestra la concentración anual de $CO_2$ atmosférico (en partes por millón) en la Antártida. Ajuste una  recta de regresión por mínimos cuadrados a los datos y determine el aumento promedio de la concentración por año.

# %%
from IPython.display import Image
Image(filename="tablas/tres.png")

# %% [markdown]
# #### Solución $$ppm = 1,87*year - 3377$$
# Coeficiente de determinación es:  0.9965075525139288<br>
# suma_cuad_err      4.176720588235335 <br>
# Ahumento promedio de la concentración por año 1,87

# %% [markdown]
# ### 4.- La siguiente tabla muestra la masa M y el consumo promedio de combustible φ de vehículos automotores fabricados por Ford y Honda en 2008. Ajustar una  recta φ = a + bM a los datos y calcular el coeficiente de determinación.

# %%
from IPython.display import Image
Image(filename="tablas/cuatro.png")

# %% [markdown]
# #### Solución $$\varphi =  -0,00583313334*M +18.4$$
# coeficiente de determinación es:  0.8329515085021111 <br>
# suma_cuad_err 13.552955939074778

# %% [markdown]
# ### 5.- La densidad relativa $\rho$ del aire se midió a varias altitudes $h$. Los resultados se muestran en la tabla siguiente. Realice un ajuste con un polinomio de segundo grado por mínimos cuadrados y determina la densidad   $\rho$ a una altura de 10.5 km

# %%
from IPython.display import Image
Image(filename="tablas/cinco.png")

# %% [markdown]
# #### Solución: $$\rho =  0.00276321*h^2 -0.09344731*h + 0.99889524$$
# Coeficiente de determinación es:  0.9999762739552294 <br>
# suma_cuad_err 7.260952380952613 E-06 <br>
# densidad a 10.5 km  0.3223423875

# %% [markdown]
# ### 6.- En un laboratorio,  se midió la intensidad de la radiación de una sustancia en intervalos de medio año como se indica en la tabla siguiente.

# %%
from IPython.display import Image
Image(filename="tablas/seis.png")

# %% [markdown]
# #### Siendo $\gamma$ la intensidad de radiación relativa. Se conoce que la radiación decae exponencialmente con el tiempo de acuerdo con la ecuación $\gamma(t) = a*e^{-b*t}$. Estimar la vida media de la sustancia ($\gamma = 0.5$).

# %% [markdown]
# #### Solución $$\gamma = 0.99841578*e^{-0.00863955*t} $$
# Coeficiente de determinación es:  0.9939510396367889 <br>
# suma_cuad_err  1.5490711846522136 E-05 <br>
# vida media = 79.9962166337 años

# %% [markdown]
# ### 7.- Se ha monitorizado la concentración de la bacteria $E coli$ en una piscina después de una tormenta y se han obtenido los siguientes datos.

# %%
from IPython.display import Image
Image(filename="tablas/siete.png")

# %% [markdown]
# #### El tiempo se ha medido en horas transcurridas después de la tormenta y la unidad CFU es una "unidad de formación de colonia". Utilizar los datos para estimar:
# #### 1. La concentración cuando finalizó la tormenta (t=0)
# #### 2. El tiempo en el que la concentración alcanza las 200 CFU/100 ml. <br>
# #### *** El modelo debería ser consistente con el echo de que no pueden haber concentraciones negativas así como que la concentración decae en el tiempo.

# %% [markdown]
# #### Solucion $$c = 1985.3*e^{-0.0546*t} $$
# Coeficiente de determinación es:  0.9904823589847215 <br>
# suma_cuad_err   5912.045633246062 <br>
# concentración a t=0 1986 bacteria <br>
# tiempo para 200 CFU 42.897 horas

# %% [markdown]
# ### 8.- Un investigador informa sobre los datos tabulados a continuación de un experimento para determinar la tasa de crecimiento de bacterias $k$ (por día), como función de la concentración de oxígeno $c$ (mg/L). Se sabe que dichos datos pueden modelarse por medio de la ecuación siguiente $$ k = \frac{k_{max}*c^{2}}{c_{s}+c^{2}}$$ donde $c_s$ y $k_{max}$ son parámetros. Use una transformación para hacer lineal esta ecuación. Después utilice regresión lineal por mínimos cuadrados para estimar $c_s$ y $k_{max}$, y pronostique la tasa de crecimiento para $c = 2 mg/L$.

# %%
from IPython.display import Image
Image(filename="tablas/ocho.png")

# %% [markdown]
# #### Solución $kmax = 10,061, cs=2,037,$
# k = 6.6666  para c = 2mg/L

# %% [markdown]
# ### 9.- La siguiente tabla muestra la variación de la conductividad térmica del sodio en relación con la temperatura. Encuentre una ecuación cuadrática que relacione ambas variables mediante regresión por mínimos cuadrados.

# %%
from IPython.display import Image
Image(filename="tablas/diez.png")

# %% [markdown]
# #### Solución $$k = 2.30985609 E-07*T^2 -6.80740001 E-04*T +1.05258944$$
# Coeficiente de determinación es:  0.9999943811526982 <br>
# suma_cuad_err   3.490944783667925 E-07

# %% [markdown]
# ### 10.- El precio de un determinado producto varía con los años que está en el mercado, tal y como se muestra en la tabla siguiente:

# %%
from IPython.display import Image
Image(filename="tablas/nueve.png")

# %% [markdown]
# #### Ajustar a estos datos los siguientes modelos utilizando mínimos cuadrados y ver cuál es el que mejor se ajusta  (x son loa años y el precio es la y).
# 1. $y =  c_{1}e^{c_{2}x}$
# 2. $ y = c_{1}*x^{c_{2}}$
# 3. $ y= c_{1}x^{2}+c_{2}x+c_{3}$
# 4. $ y= c_{1}x^{4}+c_{2}x^{3}+c_{3}x{2}+c_{4}x+c_{5}$

# %% [markdown]
# #### Soluciones
# 1. $precio = 0.00085334*e^{0.35601*años}$<br>
# coeficiente de determinación es:  0.961097784125807<br>
# suma_cuad_err 10.395
# 2. $precio = 2.26 E-7 *años^{5.147}$<br>
# coeficiente de determinación es:  0.9476364147277271<br>
# suma_cuad_err 0.6141830727859995
# 3. $precio = 0.01659*años^{2}-0.3458*años+1.7$<br>
# coeficiente de determinación es:  0.9954234018526483<br>
# suma_cuad_err 0.0891439422084624
# 4. $precio = -3.647E-05*años^{4}+ 2.5728E-03*años^{3}-4.8084 E-02*años^{2}+ 0.3327*años-0.733 $
# coeficiente de determinación es:  0.9962819337758981<br>
# suma_cuad_err 0.06276510644199446
